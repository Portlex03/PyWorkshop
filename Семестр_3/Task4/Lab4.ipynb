# %% [markdown]
# # Задане №4

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Пункт 1

# %% [markdown]
# Используйте функцию и отрезок ([a, b]) из вашего варианта задания 2
# (которые вы использовали для интегрирования). Разбейте отрезок на
# столько частей, сколько считаете нужным. Вычислите значение
# функции для всех точек получившегося массива.
#
# 𝑦 = 𝑙𝑛(sqrt(𝑥)), 𝑥0 = 2, 𝑎 = 1, 𝑏 = 6

# %%
import numpy as np
import math
x = np.arange(1,6,0.05)
y = np.vectorize(lambda x: math.log(math.sqrt(x)))
print('Значение функции для всех точек:')
y_x = y(x)
l = [print(round(line[0],3),',', round(line[1],3)) for line in np.vstack((x,y_x)).T]
# Out:
# Значение функции для всех точек:
# 1.0 , 0.0
# 1.05 , 0.024
# 1.1 , 0.048
# 1.15 , 0.07
# 1.2 , 0.091
# 1.25 , 0.112
# 1.3 , 0.131
# 1.35 , 0.15
# 1.4 , 0.168
# 1.45 , 0.186
# 1.5 , 0.203
# 1.55 , 0.219
# 1.6 , 0.235
# 1.65 , 0.25
# 1.7 , 0.265
# 1.75 , 0.28
# 1.8 , 0.294
# 1.85 , 0.308
# 1.9 , 0.321
# 1.95 , 0.334
# 2.0 , 0.347
# 2.05 , 0.359
# 2.1 , 0.371
# 2.15 , 0.383
# 2.2 , 0.394
# 2.25 , 0.405
# 2.3 , 0.416
# 2.35 , 0.427
# 2.4 , 0.438
# 2.45 , 0.448
# 2.5 , 0.458
# 2.55 , 0.468
# 2.6 , 0.478
# 2.65 , 0.487
# 2.7 , 0.497
# 2.75 , 0.506
# 2.8 , 0.515
# 2.85 , 0.524
# 2.9 , 0.532
# 2.95 , 0.541
# 3.0 , 0.549
# 3.05 , 0.558
# 3.1 , 0.566
# 3.15 , 0.574
# 3.2 , 0.582
# 3.25 , 0.589
# 3.3 , 0.597
# 3.35 , 0.604
# 3.4 , 0.612
# 3.45 , 0.619
# 3.5 , 0.626
# 3.55 , 0.633
# 3.6 , 0.64
# 3.65 , 0.647
# 3.7 , 0.654
# 3.75 , 0.661
# 3.8 , 0.668
# 3.85 , 0.674
# 3.9 , 0.68
# 3.95 , 0.687
# 4.0 , 0.693
# 4.05 , 0.699
# 4.1 , 0.705
# 4.15 , 0.712
# 4.2 , 0.718
# 4.25 , 0.723
# 4.3 , 0.729
# ...

# %% [markdown]
# ## Пункт 2

# %% [markdown]
# * Используя множество точек и множество значений функции в этих
# точках, постройте простой график функции (метод plot()).
# * Задайте графику название.
# * Подпишите оси.
# * Установите желаемые размеры шрифта для названия и подписей.
# * Добавьте на график легенду.

# %%
import matplotlib.pyplot as plt

plt.plot(x,y_x)

plt.rcParams.update({'font.size': 14})

plt.title('Функция ln(sqrt(x))')

plt.xlabel('Ось x')
plt.ylabel('Ось y')

plt.legend(['function'])
plt.show()

# %% [markdown]
# ## Пункт 3

# %% [markdown]
# - Постройте точечный график функции, в качестве меток для точек
# используйте любой любой доступный маркер.
# - Задайте графику название.
# - Подпишите оси.
# - Измените цвет точек на желаемый. Цвет задайте с помощью указания значений
# красного, зеленого и синего (по модели RGB).
# - Добавьте на график сетку.
# - Укажите цвет и непрозрачность линий сетки.

# %%
plt.plot(x,y_x, marker='o', color=(0.1, 0.2, 0.5))

plt.title('Функция ln(sqrt(x))')

plt.xlabel('Ось x')
plt.ylabel('Ось y')

plt.grid(visible=True,alpha=0.25,color=(0.3,0.2,0.4))

# %% [markdown]
# ## Пункт 4

# %% [markdown]
# - Используйте выборки из равномерного и нормального распределения (из задания 3).
# - Постройте две гистограммы.
# - Используйте различные цвета для гистограмм.
# - Установите для каждой гистограммы собственное значение количества разбиений.
# - Подпишите гистограммы.

# %%
uniform_aray = np.random.uniform(0,100,size=100)

plt.hist(uniform_aray, color='green',bins=15)

plt.title('Гистограмма равномерного распределения')
# Out:
# Text(0.5, 1.0, 'Гистограмма равномерного распределения')

# %%
normal_array = np.random.normal(size=100)

plt.hist(normal_array, color='orange',bins=25)

plt.title('Гистограмма нормального распределения')
# Out:
# Text(0.5, 1.0, 'Гистограмма нормального распределения')

# %% [markdown]
# ## Пункт 5

# %% [markdown]
# - Сгенерируйте выборку из равномерного распределения, состоящую из 50 целых чисел от 1 до 5 (не включая 5).
# - Посчитайте, сколько раз встречается каждое из чисел в выборке (без циклов!).
# - На основе полученной информации постройте круговую и столбчатую диаграммы.
# - Подпишите диаграммы.
# - Для круговой диаграммы укажите подписи секторов.
# - Для столбчатой диаграммы укажите подписи столбцов.
# - Для обеих диаграмм укажите множество используемых цветов (для раскраски секторов и столбцов).

# %%
uniform_aray = np.random.randint(1,5,size=50)
print(uniform_aray)
# Out:
# [2 2 4 1 1 4 2 2 3 3 3 1 2 1 2 4 4 2 2 3 1 2 1 3 2 3 4 3 4 2 1 3 4 2 1 2 2
#  1 3 1 4 2 3 1 3 4 2 3 1 3]

# %%
from collections import Counter

info = dict(Counter(uniform_aray))
for i in info.keys():
    print(i,':',info[i])
# Out:
# 2 : 16
# 4 : 9
# 1 : 12
# 3 : 13

# %%
plt.pie(
    x=list(info.values()), 
    labels=list(info.keys()),
    autopct='%1.1f%%',
    colors=['red','orange','yellow','green']
)
plt.title('Круговая диаграмма равномерного распределения')
plt.show()

# %%
plt.bar(
    x=list(map(str,info.keys())),
    height=list(info.values()),
    color=['blue','greenyellow','gold','olivedrab']
)
plt.title('Столбчатая диаграмма равномерного распределения')
plt.show()

# %% [markdown]
# ## Пункт 6

# %% [markdown]
# - Используя знания о разбиении отрезка на множество точек (из пункта
# 1), а также функцию с несколькими переменными из задания 2 (которая
# использовалась для решения задачи оптимизации), постройте
# трехмерный график функции.
# - Установите цвет линии на графике.
# - Важно: если в вашем варианте к заданию 2 функция состояла более чем
# из двух переменных - используйте только первые две переменные.
#
# (𝑥1 - 3)^2 + (𝑥2 − 1)^2 → 𝑚𝑖𝑛

# %%
x = np.arange(1,10,0.05)
y = np.arange(1,10,0.05)

f = np.vectorize(lambda x,y: (x - 3)**2 + (y - 1)**2)
z = f(x,y)

ax = plt.figure().add_subplot(111, projection='3d').plot(x, y, z, color='red')
plt.title('Функция (x-3)^2 + (y-1)^2')
plt.show()

# %% [markdown]
# ## Задание 7

# %% [markdown]
# - Используя подграфики (subplots) постройте сетку 2x2 из 4 графиков.
# - Установите размер сетки.
# - Добавьте заголовок сетки, укажите размер шрифта.
#     - В левом верхнем углу сетки разместите график из пункта 2 текущего задания,
#     - в правом верхнем - из пункта 3.
#     - В левом нижнем - круговую диаграмму из пункта 5.
#     - В правом нижнем - трехмерныйграфик из пункта 6.
# - Для любого из графиков установите цвет фона.

# %%
def show_grafics(fig):
    plt.subplots_adjust(left=0.13, right=0.93, top=1.0, bottom= 0.27, wspace= 0.3, hspace=0.3)

    ################ 1 рисунок #######################
    x = np.arange(1,6,0.05)
    y = np.vectorize(lambda x: math.log(math.sqrt(x)))
    y_x = y(x)

    fig.add_subplot(221).set_facecolor('#AFAFAF')
    plt.plot(x,y_x)
    plt.title('Функция ln(sqrt(x))')

    ################ 2 рисунок #######################
    fig.add_subplot(222)
    plt.plot(x,y_x, marker='o', color=(0.1, 0.2, 0.5))
    plt.grid(visible=True,alpha=0.25,color=(0.3,0.2,0.4))
    plt.title('Функция ln(sqrt(x))')

    ################ 3 рисунок #######################
    fig.add_subplot(223)
    plt.pie(
        x=list(info.values()), 
        labels=list(info.keys()),
        autopct='%1.1f%%',
        colors=['red','orange','yellow','green']
    )
    plt.title('Круговая диаграмма равномерного распределения')

    ################ 4 рисунок #######################
    fig.add_subplot(224,projection='3d')
    x = np.arange(1,10,0.05)
    y = np.arange(1,10,0.05)
    f = np.vectorize(lambda x,y: (x - 3)**2 + (y - 1)**2)
    z = f(x,y)
    plt.plot(x, y, z, 'green')
    plt.title('Функция (x-3)^2 + (y-1)^2')

    plt.show()

# %%
show_grafics(plt.figure(figsize=[20,15]))

# %% [markdown]
# ## Задание 8

# %% [markdown]
# - Посмотрите доступные в pyplot стили оформления графиков.
# - Попробуйте 3 любых стиля на ваш выбор.
# - Для каждого стиля:
#     * установите его,
#     * отобразите сетку графиков из пункта 6.
# - Таким образом, всего за это задание сетка из 4 графиков должна быть отображена 4 раза.
# - Замечание: если установка стиля не изменяет внешнего вида графика - не расстраивайтесь. Многие стили предназначены для установки цветовой палитры, а по заданию вы сами устанавливали цвета. Если не видите изменений - просто переходите к следующему стилю.

# %%
plt.style.use('seaborn-ticks')
fig = plt.figure(figsize=[20,15])

show_grafics(fig)

# %%
plt.style.use('grayscale')
fig = plt.figure(figsize=[20,15])

show_grafics(fig)

# %%
plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=[20,15])

show_grafics(fig)
