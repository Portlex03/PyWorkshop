# %% [markdown]
# # Задание 5

# %% [markdown]
# ## Номер 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

df1 = pd.DataFrame(
    [['Strom, Mrs. Wilhelm (Elna Matilda Persson)', 29   , 'female'],
     ['Navratil, Mr. Michel ("Louis M Hoffman")'  , 36.5 , 'male'  ],
     ['Minahan, Miss. Daisy E'                    , 33   , 'female']], 
    columns=['Name','Age','Sex']
)

# %%
df1
# Out:
#                                          Name   Age     Sex
# 0  Strom, Mrs. Wilhelm (Elna Matilda Persson)  29.0  female
# 1    Navratil, Mr. Michel ("Louis M Hoffman")  36.5    male
# 2                      Minahan, Miss. Daisy E  33.0  female

# %% [markdown]
# # Номер 2 и 3

# %% [markdown]
# 2. Загрузите данные из файла:
# https://drive.google.com/file/d/16gikf9vvMLyldkdHtoDYrPDbqTHP1BxG/view?usp=share_link
# 3. Загрузите напрямую данные по ссылке:
# https://gist.githubusercontent.com/zaryanezrya/8b4ef51c707cb16d5e88a44dc00a1bb2/raw/41230f49c6268e072dbf102672f670be256922ab/gistfile1.txt (read_csv).

# %%
df2 = pd.read_csv('Data/titanic_csv.csv',sep=';')
df3 = pd.read_csv('Data/data3.csv')

# %% [markdown]
# # Номер 4
# Объедините датафреймы из п. 2, 3 в один датафрейм, удалите дубликаты
# строк.

# %%
df2.head(2)
# Out:
#    PassengerId  Survived  Pclass                            Name     Sex  \
# 0          454         1       1        Goldenberg, Mr. Samuel L    male
# 1          234         1       3  Asplund, Miss. Lillian Gertrud  female
#
#     Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 0  49.0      1      0   17453  89.1042   C92        C
# 1   5.0      4      2  347077  31.3875   NaN        S

# %%
df3.head(2)
# Out:
#    passengerid  survived  pclass                             name   sex   age  \
# 0          552         0       2      Sharp, Mr. Percival James R  male  27.0
# 1          689         0       3  Fischer, Mr. Eberhard Thelander  male  18.0
#
#    sibsp  parch  ticket     fare cabin embarked
# 0      0      0  244358  26.0000   NaN        S
# 1      0      0  350036   7.7958   NaN        S

# %%
df2 = df2.rename(columns=lambda x: x.lower())
df = pd.concat((df2,df3),)
df.head(3)
# Out:
#    passengerid  survived  pclass                            name     sex  \
# 0          454         1       1        Goldenberg, Mr. Samuel L    male
# 1          234         1       3  Asplund, Miss. Lillian Gertrud  female
# 2          556         0       1              Wright, Mr. George    male
#
#     age  sibsp  parch  ticket     fare cabin embarked
# 0  49.0      1      0   17453  89.1042   C92        C
# 1   5.0      4      2  347077  31.3875   NaN        S
# 2  62.0      0      0  113807  26.5500   NaN        S

# %%
df = df.drop_duplicates()

# %% [markdown]
# # Номер 5
# Задайте в качестве индекса датафрейма id пассажира. Отсортируйте по
# индексу (sort_values).

# %%
df.index = df['passengerid']
df = df.drop('passengerid',axis=1)
df = df.sort_index()
df.head(3)
# Out:
#              survived  pclass  \
# passengerid
# 1                   0       3
# 2                   1       1
# 3                   1       3
#
#                                                           name     sex   age  \
# passengerid
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
#
#              sibsp  parch            ticket     fare cabin embarked
# passengerid
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# # Номер 6
# Отобразите информацию и базовую статистику по датафрейму (info, describe)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   name      891 non-null    object
#  3   sex       891 non-null    object
#  4   age       714 non-null    float64
#  5   sibsp     891 non-null    int64
#  6   parch     891 non-null    int64
#  7   ticket    891 non-null    object
#  8   fare      891 non-null    float64
#  9   cabin     204 non-null    object
#  10  embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# # Номер 7
# Поменяйте местами нулевую по порядку строку с элементом с индексом 2 (loc,
# iloc).

# %%
df.head(3)
# Out:
#              survived  pclass  \
# passengerid
# 1                   0       3
# 2                   1       1
# 3                   1       3
#
#                                                           name     sex   age  \
# passengerid
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
#
#              sibsp  parch            ticket     fare cabin embarked
# passengerid
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.iloc[0], df.loc[2] = df.loc[2], df.iloc[0]
df.head(3)
# Out:
#              survived  pclass  \
# passengerid
# 1                   1       1
# 2                   0       3
# 3                   1       3
#
#                                                           name     sex   age  \
# passengerid
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                                      Braund, Mr. Owen Harris    male  22.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
#
#              sibsp  parch            ticket     fare cabin embarked
# passengerid
# 1                1      0          PC 17599  71.2833   C85        C
# 2                1      0         A/5 21171   7.2500   NaN        S
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# # Номер 8
# В столбце Sex замените female/male на f/m (map).

# %%
df['sex'] = df['sex'].apply(lambda x: x[:1])
df.head(3)
# Out:
#              survived  pclass  \
# passengerid
# 1                   1       1
# 2                   0       3
# 3                   1       3
#
#                                                           name sex   age  \
# passengerid
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...   f  38.0
# 2                                      Braund, Mr. Owen Harris   m  22.0
# 3                                       Heikkinen, Miss. Laina   f  26.0
#
#              sibsp  parch            ticket     fare cabin embarked
# passengerid
# 1                1      0          PC 17599  71.2833   C85        C
# 2                1      0         A/5 21171   7.2500   NaN        S
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# # Номер 9

# %% [markdown]
# Найдите билеты по которым плыло 6 и более человек, отобразите список людей
# (groupby, count)

# %%
# df[df['ticket'] == '110152']
tickets = df.groupby('ticket').count().query('survived >= 6')
tickets
# Out:
#           survived  pclass  name  sex  age  sibsp  parch  fare  cabin  \
# ticket
# 1601             7       7     7    7    4      7      7     7      0
# 3101295          6       6     6    6    6      6      6     6      0
# 347082           7       7     7    7    7      7      7     7      0
# 347088           6       6     6    6    6      6      6     6      0
# CA 2144          6       6     6    6    6      6      6     6      0
# CA. 2343         7       7     7    7    0      7      7     7      0
#
#           embarked
# ticket
# 1601             7
# 3101295          6
# 347082           7
# 347088           6
# CA 2144          6
# CA. 2343         7

# %%
df[df['ticket'].isin(tickets.index)]
# Out:
#              survived  pclass  \
# passengerid
# 14                  0       3
# 51                  0       3
# 60                  0       3
# 64                  0       3
# 72                  0       3
# 75                  1       3
# 120                 0       3
# 160                 0       3
# 165                 0       3
# 168                 0       3
# 170                 0       3
# 181                 0       3
# 202                 0       3
# 267                 0       3
# 325                 0       3
# 361                 0       3
# 387                 0       3
# 481                 0       3
# 510                 1       3
# 542                 0       3
# 543                 0       3
# 611                 0       3
# 635                 0       3
# 639                 0       3
# 643                 0       3
# 644                 1       3
# 679                 0       3
# 684                 0       3
# 687                 0       3
# ...

# %% [markdown]
# # Номер 10

# %% [markdown]
# Найдите людей, которые плыли в одной каюте с людьми из датафрейма из п1

# %%
persons = df[df['name'].isin(df1['Name'])]
persons
# Out:
#              survived  pclass                                        name sex  \
# passengerid
# 149                 0       2    Navratil, Mr. Michel ("Louis M Hoffman")   m
# 252                 0       3  Strom, Mrs. Wilhelm (Elna Matilda Persson)   f
# 413                 1       1                      Minahan, Miss. Daisy E   f
#
#               age  sibsp  parch  ticket     fare cabin embarked
# passengerid
# 149          36.5      0      2  230080  26.0000    F2        S
# 252          29.0      1      1  347054  10.4625    G6        S
# 413          33.0      1      0   19928  90.0000   C78        Q

# %%
answer = df[df['cabin'].isin(persons['cabin']) & ~df['name'].isin(df1['Name'])]
answer
# Out:
#              survived  pclass  \
# passengerid
# 11                  1       3
# 194                 1       2
# 206                 0       3
# 246                 0       1
# 341                 1       2
# 395                 1       3
#
#                                                           name sex   age  \
# passengerid
# 11                             Sandstrom, Miss. Marguerite Rut   f   4.0
# 194                                 Navratil, Master. Michel M   m   3.0
# 206                                 Strom, Miss. Telma Matilda   f   2.0
# 246                                Minahan, Dr. William Edward   m  44.0
# 341                             Navratil, Master. Edmond Roger   m   2.0
# 395          Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...   f  24.0
#
#              sibsp  parch   ticket     fare cabin embarked
# passengerid
# 11               1      1  PP 9549  16.7000    G6        S
# 194              1      1   230080  26.0000    F2        S
# ...

# %%
answer.shape
# Out:
# (6, 11)

# %% [markdown]
# # Номер 11

# %% [markdown]
# Добавьте колонку “BirthYear” с годом рождения каждого пассажира

# %%
df['birthYear'] = 1912 - df['age']
df.head(3)
# Out:
#              survived  pclass  \
# passengerid
# 1                   1       1
# 2                   0       3
# 3                   1       3
#
#                                                           name sex   age  \
# passengerid
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...   f  38.0
# 2                                      Braund, Mr. Owen Harris   m  22.0
# 3                                       Heikkinen, Miss. Laina   f  26.0
#
#              sibsp  parch            ticket     fare cabin embarked  birthYear
# passengerid
# 1                1      0          PC 17599  71.2833   C85        C     1874.0
# 2                1      0         A/5 21171   7.2500   NaN        S     1890.0
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S     1886.0

# %% [markdown]
# # Номер 12

# %% [markdown]
# Добавьте колонку “Companion” с количеством попутчиков в одной каюте с этим
# пассажиром

# %%
df['Companion'] = df.groupby('cabin')['name'].transform('count') - 1
df.head()
# Out:
#              survived  pclass  \
# passengerid
# 1                   1       1
# 2                   0       3
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           name sex   age  \
# passengerid
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...   f  38.0
# 2                                      Braund, Mr. Owen Harris   m  22.0
# 3                                       Heikkinen, Miss. Laina   f  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   f  35.0
# 5                                     Allen, Mr. William Henry   m  35.0
#
#              sibsp  parch            ticket     fare cabin embarked  \
# passengerid
# 1                1      0          PC 17599  71.2833   C85        C
# 2                1      0         A/5 21171   7.2500   NaN        S
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# # Номер 13

# %% [markdown]
# Поменяйте местами нулевую по порядку строку с элементом с индексом 1

# %%
df.head(3)
# Out:
#              survived  pclass  \
# passengerid
# 1                   1       1
# 2                   0       3
# 3                   1       3
#
#                                                           name sex   age  \
# passengerid
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...   f  38.0
# 2                                      Braund, Mr. Owen Harris   m  22.0
# 3                                       Heikkinen, Miss. Laina   f  26.0
#
#              sibsp  parch            ticket     fare cabin embarked  \
# passengerid
# 1                1      0          PC 17599  71.2833   C85        C
# 2                1      0         A/5 21171   7.2500   NaN        S
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
#
#              birthYear  Companion
# passengerid
# 1               1874.0        0.0
# 2               1890.0        NaN
# 3               1886.0        NaN

# %%
df.iloc[0], df.loc[1] = df.loc[1], df.iloc[0]
df.head(3)
# Out:
#              survived  pclass  \
# passengerid
# 1                   1       1
# 2                   0       3
# 3                   1       3
#
#                                                           name sex   age  \
# passengerid
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...   f  38.0
# 2                                      Braund, Mr. Owen Harris   m  22.0
# 3                                       Heikkinen, Miss. Laina   f  26.0
#
#              sibsp  parch            ticket     fare cabin embarked  \
# passengerid
# 1                1      0          PC 17599  71.2833   C85        C
# 2                1      0         A/5 21171   7.2500   NaN        S
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
#
#              birthYear  Companion
# passengerid
# 1               1874.0        0.0
# 2               1890.0        NaN
# 3               1886.0        NaN

# %% [markdown]
# # Номер 14

# %% [markdown]
# Запишите получившийся датафрейм в csv файл (to_csv)

# %%
df.to_csv('dataframe.csv')

# %% [markdown]
# # Номер 15

# %% [markdown]
# Отобразите топ-10 людей, которые больше остальных заплатили за билет

# %%
df[['name', 'fare']].sort_values(by='fare', ascending=False).head(10)
# Out:
#                                               name      fare
# passengerid
# 259                               Ward, Miss. Anna  512.3292
# 680             Cardeza, Mr. Thomas Drake Martinez  512.3292
# 738                         Lesurer, Mr. Gustave J  512.3292
# 28                  Fortune, Mr. Charles Alexander  263.0000
# 439                              Fortune, Mr. Mark  263.0000
# 89                      Fortune, Miss. Mabel Helen  263.0000
# 342                 Fortune, Miss. Alice Elizabeth  263.0000
# 743          Ryerson, Miss. Susan Parker "Suzette"  262.3750
# 312                     Ryerson, Miss. Emily Borie  262.3750
# 119                       Baxter, Mr. Quigg Edmond  247.5208

# %% [markdown]
# # Номер 16

# %% [markdown]
# Отобразите сколько женщин и мужчин выжило/не выжило

# %%
df.groupby(['sex', 'survived'])['sex'].count()
# Out:
# sex  survived
# f    0            81
#      1           233
# m    0           468
#      1           109
# Name: sex, dtype: int64

# %% [markdown]
# # Номер 17

# %% [markdown]
# Отобразите сколько в каком классе пассажиров выжило/не выжило.

# %%
df.groupby(['survived', 'pclass'])['survived'].count()
# Out:
# survived  pclass
# 0         1          80
#           2          97
#           3         372
# 1         1         136
#           2          87
#           3         119
# Name: survived, dtype: int64
